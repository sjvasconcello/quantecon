# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## The APIs
# ### The MATLAB-style API

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.linspace(0,20,100)
y = np.sin(x)

plt.plot(x,y, linewidth=2)
plt.show()

# %% [markdown]
# ### The Object Oriented API

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'b-',linewidth=3)
plt.show()

# %% [markdown]
# ### Tweaks

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'r-', linewidth=2, label='Sine function', alpha=0.8)
ax.legend(loc='lower left')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'r-', linewidth=2, label='Sine function', alpha=0.6)
ax.legend(loc='upper center')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y, 'r-', linewidth=2, label='$y=\sin(x)$', alpha=0.4)
ax.legend(loc='upper center')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y, 'r-', linewidth=2, label='$y=\sin(x)$', alpha=0.6)
ax.legend(loc='upper center')
ax.set_yticks([-5, 0, 5])
ax.set_title('Test plot')
plt.show()

# %% [markdown]
# ## More Feactures
# ### Multiple Plots on One Axis

# %%
from scipy.stats import norm
from random import uniform

fig, ax = plt.subplots()
x = np.linspace(-10,10,300)
for i in range(3):
    m, s = uniform(-1,1), uniform(1,6)
    y = norm.pdf(x, loc=m, scale=s)
    current_label = f'$\mu = {m:.2}$'
    ax.plot(x,y, linewidth=2, alpha=0.6, label=current_label)
ax.legend()
plt.show()

# %% [markdown]
# ### Multiple Subplots

# %%
num_rows, num_cols = 3, 2
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10,12))
for i in range(num_rows):
    for j in  range(num_cols):
        m, s = uniform(-1,1), uniform(1,2)
        x = norm.rvs(loc=m, scale=s, size=100)
        axes[i,j].hist(x, alpha=0.6, bins=20)
        t = f'$\mu = {m:.2}, \quad \sigma = {s:.2}$'
        axes[i, j].set(title=t, xticks=[-4, 0, 4], yticks=[])
plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

xgrid = np.linspace(-3, 3, 50)
ygrid = xgrid
x, y = np.meshgrid(xgrid, ygrid)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,
                y,
                f(x, y),
                rstride=2, cstride=2,
                cmap=cm.jet,
                alpha=0.7,
                linewidth=0.25)
ax.set_zlim(-1, 0.5)
plt.show()

# %% [markdown]
# ### A Customizing Function

# %%
def subplots():
    "Custom subplots with axes throught the origin"
    fig, ax = plt.subplots()

    # Set the axes through the origin
    for spine in ['left', 'bottom']:
        ax.spines[spine].set_position('zero')
    for spine in ['right', 'top']:
        ax.spines[spine].set_color('none')

    ax.grid()
    return fig, ax


fig, ax = subplots()  # Call the local version, not plt.subplots()
x = np.linspace(-10, 10, 200)
y = np.sin(x)
ax.plot(x, y, 'r-', linewidth=2, label='sine function', alpha=0.6)
ax.legend(loc='lower right')

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# $$f(x) = \cos(\pi\theta x)\exp(-x)$$

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

theta_vals = np.linspace(-10, 10, 20)
x = np.linspace(-5,0,10)

fig, ax = plt.subplots()
 
for i in theta_vals:
    ax.plot(x, np.cos(np.pi*i*x)*np.exp(-x))
    

plt.show()
